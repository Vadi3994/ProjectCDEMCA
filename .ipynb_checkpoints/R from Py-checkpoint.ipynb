# %%
import rpy2.robjects as robjects
import rpy2.robjects.packages as rpackages
from rpy2.robjects.vectors import StrVector

# %%
packageNames = ('afex', 'emmeans')
utils = rpackages.importr('utils')
utils.chooseCRANmirror(ind=1)

packnames_to_install = [x for x in packageNames if not rpackages.isinstalled(x)]

if len(packnames_to_install) > 0:
    utils.install_packages(StrVector(packnames_to_install))

# %%
data = robjects.r('read.table(file ="http://personality-project.org/r/datasets/R.appendix3.data", header = T)')
data.head()
# Out:
# R object with classes: ('data.frame',) mapped to:
# <DataFrame - Python:0x000001AF18BAE788 / R:0x000001AF308A1518>
# [IntVector, FactorVector, FactorVector, IntVector]
#   Observation: <class 'rpy2.robjects.vectors.IntVector'>
#   R object with classes: ('integer',) mapped to:
# <IntVector - Python:0x000001AF303CBD88 / R:0x000001AF308A1388>
# [1, 2, 3, 4, 5, 6]
#   Subject: <class 'rpy2.robjects.vectors.FactorVector'>
#   R object with classes: ('factor',) mapped to:
# <FactorVector - Python:0x000001AF23268748 / R:0x000001AF308A12E8>
# [Jim, Jim, Jim, Victor, Victor, Victor]
#   Valence: <class 'rpy2.robjects.vectors.FactorVector'>
#   R object with classes: ('factor',) mapped to:
# <FactorVector - Python:0x000001AF23268448 / R:0x000001AF308A1248>
# [Neg, Neu, Pos, Neg, Neu, Pos]
#   Recall: <class 'rpy2.robjects.vectors.IntVector'>
#   R object with classes: ('integer',) mapped to:
# <IntVector - Python:0x000001AF23268E48 / R:0x000001AF308A11A8>
# [32, 15, 45, 30, 13, 40]

# %%
afex = rpackages.importr('afex')
model = afex.aov_ez('Subject', 'Recall', data, within='Valence')
print(model)
# Out:
# Anova Table (Type 3 tests)
#
#
#
# Response: Recall
#
#    Effect         df  MSE          F ges p.value
#
# 1 Valence 1.15, 4.60 9.34 189.11 *** .93  <.0001
#
# ---
#
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '+' 0.1 ' ' 1
#
#
#
# Sphericity correction method: GG

# %%
# %load_ext rpy2.ipython
# %Rdevice png
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# barplot(c(1,3,2,5,4), ylab="value")

# %%
# %%R
# require(ggplot2)
# gg <- ggplot(mtcars, aes(x=wt, y=mpg)) + geom_point(aes(colour='qsec')) + theme_bw()
#
# gg

# %%
import pandas as pd
customer_data=pd.read_csv("C:/Users/velu3/Documents/GitHub/ProjectCDEMCA/Data/Mall_Customers.csv")
str(customer_data)
customer_data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
# %load_ext rpy2.ipython
# %Rdevice png
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
#
# customer_data=read.csv("C:/Users/velu3/Documents/GitHub/ProjectCDEMCA/Data/Mall_Customers.csv")
#
# png(file = "C:/Users/velu3/Documents/GitHub/ProjectCDEMCA/Web_App/static/Web_App/RGraphs/barchart_months_revenue1.png")
#
# hist(customer_data$Age,
#      col="blue",
#      main="Histogram to Show Count of Age Class",
#      xlab="Age Class",
#      ylab="Frequency",
#      labels=TRUE)
#
# dev.off()
